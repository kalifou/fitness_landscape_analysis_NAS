# %%
from pyDOE import *
import matplotlib.pyplot as plt# Standard imports
import copy
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns 

# Fixing random state for reproducibility
np.random.seed(19680801)

# %%
import pickle as pkl

# %%
path_meta_1 = 'half1/lcz42_sen2_d2_trial_2_incremental_meta.data'
# /local_home/trao_ka/projects/results_from_server/backup_lcz42_nb101/half1/lcz42_sen2_d2_trial_2_incremental_meta.data'
path_meta_2 = 'half2/lcz42_sen2_d2_trial_1_incremental_meta.data'
# '/local_home/trao_ka/projects/results_from_server/backup_lcz42_nb101/half2/lcz42_sen2_d2_trial_1_incremental_meta.data'
with open(path_meta_1, 
          'rb') as filehandle:
    # read the data as bina|ry data stream
    read_data_1 = pkl.load(filehandle)

with open(path_meta_2,
          'rb') as filehandle:
    # read the data as bina|ry data stream
    read_data_2 = pkl.load(filehandle)   


import glob2
extra_path_meta_2 = 'half2/*2_meta.data'
# '/local_home/trao_ka/projects/results_from_server/backup_lcz42_nb101/half2/*2_meta.data'
more_dfiles_2 = glob2.glob(extra_path_meta_2)

read_data_2['trial_2'] = []
for fname in more_dfiles_2:
    with open(fname, 'rb') as filehandle:
        # read the data as binary data stream
        d = pkl.load(filehandle)
        read_data_2['trial_2'].append(d)

all_data_0 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]       
#all_data_12 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]    
#all_data_36 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]
#all_data_108 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]    

#assert len(all_data_4) == len(all_data_12)
#assert len(all_data_12) == len(all_data_36)
#assert len(all_data_36) == len(all_data_108)
assert len(all_data_0) == 100

y_training_time_4 = np.array([d[4]['training_time'] for d in all_data_0]) /3600 # max(y_training_time_108)
y_training_time_12 = np.array([d[12]['training_time'] for d in all_data_0]) / 3600 #max(y_training_time_108)
y_training_time_36 = np.array([d[36]['training_time'] for d in all_data_0]) / 3600 #max(y_training_time_108)
y_training_time_108 = np.array([d[108]['training_time'] for d in all_data_0])/ 3600 # max(y_training_time_108)

plt.figure(figsize=(15,6))
plt.xlim(0, max(y_training_time_108))
sns.distplot(y_training_time_4, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of training_time 4e", rug=False)
sns.distplot(y_training_time_12, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 12e", rug=False)
sns.distplot(y_training_time_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 36e", rug=False)
sns.distplot(y_training_time_108, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 108e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Training time (H)')
plt.show()

# %%
sum(y_training_time_108)*3/24
# Out:
# 60.69561608720985

# %%
min(y_training_time_108), max(y_training_time_108), np.average(y_training_time_108)
# Out:
# (0.11146509024831984, 13.008105707830852, 4.855649286976789)

# %%
y_test_kappa_4 = [d[4]['kappaCohen_test'] for d in all_data_0]
y_test_kappa_12 = [d[12]['kappaCohen_test'] for d in all_data_0]
y_test_kappa_36 = [d[36]['kappaCohen_test'] for d in all_data_0]
y_test_kappa_108 = [d[108]['kappaCohen_test'] for d in all_data_0]


plt.figure(figsize=(15,6))
plt.xlim(0, 1)
sns.distplot(y_test_kappa_4, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of kappa test 4e", rug=False)
sns.distplot(y_test_kappa_12, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa test 12e", rug=False)
sns.distplot(y_test_kappa_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa test 36e", rug=False)
#sns.distplot(y_test_kappa_108, hist = False, kde = True,
#                 kde_kws = {'linewidth': 1},
#                 label = "Density of train 108e", rug=True)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
y_train_kappa_36 = [d[36]['kappaCohen_train'] for d in all_data_0]

plt.figure(figsize=(15,6))
plt.xlim(0, 1)
sns.distplot(y_train_kappa_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of kappa on train for 4e", rug=False)
sns.distplot(y_test_kappa_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa on test for 4e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
y_train_kappa_108 = [d[108]['kappaCohen_train'] for d in all_data_0]

plt.figure(figsize=(15,6))
sns.distplot(y_train_kappa_108, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of kappa on train for 108e", rug=False)
sns.distplot(y_test_kappa_108, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa on test for 108e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
min(y_test_kappa_108), max(y_test_kappa_108), np.average(y_test_kappa_108)
# Out:
# (0.9086675656063916, 0.9833121532313437, 0.969490927635508)

# %%
plt.figure(figsize=(15,10))
plt.xlim(0, 1)
sns.distplot(y_test_kappa_4, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of kappa test 4e", rug=False)
sns.distplot(y_test_kappa_12, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa test 12e", rug=False)
sns.distplot(y_test_kappa_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa test 36e", rug=False)
sns.distplot(y_test_kappa_108, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of kappa test 108e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
all_data_0 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]    
all_data_1 = [ dt for (m, op, dt) in read_data_1['trial_1']] + [ dt for (m, op, dt) in read_data_2['trial_1']] 
all_data_2 = [ dt for (m, op, dt) in read_data_1['trial_2']] + [ dt for dt in read_data_2['trial_2']]

# %%
y_test_kappa_36_0 = [d[36]['kappaCohen_test'] for d in all_data_0]
y_test_kappa_36_1 = [d[36]['kappaCohen_test'] for d in all_data_1]
y_test_kappa_36_2 = [d[36]['kappaCohen_test'] for d in all_data_2]

plt.figure(figsize=(15,6))
sns.distplot(y_test_kappa_36_0, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of 108e trial 1", rug=True)
sns.distplot(y_test_kappa_36_1, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of 108e trial 3", rug=True)
sns.distplot(y_test_kappa_36_2, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of of 108e trial 2", rug=True)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
y_test_kappa_108_0 = [d[108]['kappaCohen_test'] for d in all_data_0]
y_test_kappa_108_1 = [d[108]['kappaCohen_test'] for d in all_data_1]
y_test_kappa_108_2 = [d[108]['kappaCohen_test'] for d in all_data_2]

plt.figure(figsize=(15,6))
sns.distplot(y_test_kappa_108_0, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of 108e trial 1", rug=True)
sns.distplot(y_test_kappa_108_1, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of 108e trial 3", rug=True)
sns.distplot(y_test_kappa_108_2, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of of 108e trial 2", rug=True)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
len(read_data_2['trial_1'])
# Out:
# 50

# %%
# '/local_home/trao_ka/projects/results_from_server/backup_lcz42_nb101/half1/lcz42_sen2_d2_trial_2_incremental_meta.data'
#'/local_home/trao_ka/projects/results_from_server/backup_lcz42_nb101/half2/lcz42_sen2_d2_trial_1_incremental_meta.data'
# '/local_home/trao_ka/projects/results_from_server/backup_lcz42_nb101/half2/*2_meta.data'

path_meta_1 = 'half1/lcz42_sen2_d2_trial_2_incremental_meta.data'
path_meta_2 = 'half2/lcz42_sen2_d2_trial_1_incremental_meta.data'
extra_path_meta_2 = 'half2/*2_meta.data'

with open(path_meta_1, 
          'rb') as filehandle:
    # read the data as bina|ry data stream
    read_data_1 = pkl.load(filehandle)

with open(path_meta_2,
          'rb') as filehandle:
    # read the data as bina|ry data stream
    read_data_2 = pkl.load(filehandle)   


import glob2
more_dfiles_2 = glob2.glob(extra_path_meta_2)

read_data_2['trial_2'] = []
for fname in more_dfiles_2:
    with open(fname, 'rb') as filehandle:
        # read the data as binary data stream
        d = pkl.load(filehandle)
        read_data_2['trial_2'].append(d)

all_data_0 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]   

y_training_time_4 = np.array([d[4]['training_time'] for d in all_data_0]) /3600 # max(y_training_time_108)
y_training_time_12 = np.array([d[12]['training_time'] for d in all_data_0]) / 3600 #max(y_training_time_108)
y_training_time_36 = np.array([d[36]['training_time'] for d in all_data_0]) / 3600 #max(y_training_time_108)
y_training_time_108 = np.array([d[108]['training_time'] for d in all_data_0])/ 3600 # max(y_training_time_108)

# %%
len_t0_half = 50

mean_perf_half1 = []
std_perf_half1 = []

for m_i in range(len_t0_half):
    m0, op0, d0 = read_data_1['trial_0'][m_i]
    m1, op1, d1 = read_data_1['trial_1'][m_i]
    m2, op2, d2 = read_data_1['trial_2'][m_i]
    
    assert np.all(m0 == m1) and np.all(m1 == m2)
    assert np.all(op0 == op1) and np.all(op1 == op2)
    
    d_mean = {}
    d_std = {}
    all_regimes = [4, 12, 36, 108]
    d0_keys = [*d0]
    d1_keys = [*d1]
    d2_keys = [*d2]
    assert d0_keys == all_regimes and d1_keys == all_regimes and d2_keys == all_regimes
    
    all_attributes = [*d0[all_regimes[0]]]

    for r_i in all_regimes:
        d_mean[r_i] = {}
        d_std[r_i] = {}
    
        for at_i in all_attributes:
            d_mean[r_i][at_i] = np.mean([d0[r_i][at_i], d1[r_i][at_i], d2[r_i][at_i]])            
            d_std[r_i][at_i] = np.std([d0[r_i][at_i], d1[r_i][at_i], d2[r_i][at_i]])
            #print(d0[r_i][at_i], d0[r_i][at_i], d0[r_i][at_i])
    mean_perf_half1.append(d_mean)
    std_perf_half1.append(d_std)

# %%
len_t0_half = 50

mean_perf_half2 = []
std_perf_half2 = []

for m_i in range(len_t0_half):
    m0, op0, d0 = read_data_2['trial_0'][m_i]
    m1, op1, d1 = read_data_2['trial_1'][m_i]
    #m2, op2, d2 = read_data_2['trial_2'][m_i]
    
    assert np.all(m0 == m1) #and np.all(m1 == m2)
    assert np.all(op0 == op1) #and np.all(op1 == op2)
    
    d_mean = {}
    d_std = {}
    all_regimes = [4, 12, 36, 108]
    d0_keys = [*d0]
    d1_keys = [*d1]
    #d2_keys = [*d2]
    assert d0_keys == all_regimes and d1_keys == all_regimes #and d2_keys == all_regimes
    
    all_attributes = [*d0[all_regimes[0]]]

    for r_i in all_regimes:
        d_mean[r_i] = {}
        d_std[r_i] = {}
    
        for at_i in all_attributes:
            d_mean[r_i][at_i] = np.mean([d0[r_i][at_i], d1[r_i][at_i]]) #, d2[r_i][at_i]])            
            d_std[r_i][at_i] = np.std([d0[r_i][at_i], d0[r_i][at_i]]) #, d0[r_i][at_i]])
    
    mean_perf_half2.append(d_mean)
    std_perf_half2.append(d_std)

# %%
 #+ mean_perf_half2#mean_perf_half

# %%
#mean_perf_half

# %%
mean_perf_half = mean_perf_half1 + mean_perf_half2


y_training_time_4_m = np.array([d[4]['training_time'] for d in mean_perf_half]) /3600 # max(y_training_time_108)
y_training_time_12_m = np.array([d[12]['training_time'] for d in mean_perf_half]) / 3600 #max(y_training_time_108)
y_training_time_36_m = np.array([d[36]['training_time'] for d in mean_perf_half]) / 3600 #max(y_training_time_108)
y_training_time_108_m = np.array([d[108]['training_time'] for d in mean_perf_half]) / 3600 # max(y_training_time_108)


all_data_0 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']] 

y_training_time_4 = np.array([d[4]['training_time'] for d in all_data_0]) /3600 # max(y_training_time_108)
y_training_time_12 = np.array([d[12]['training_time'] for d in all_data_0]) / 3600 #max(y_training_time_108)
y_training_time_36 = np.array([d[36]['training_time'] for d in all_data_0]) / 3600 #max(y_training_time_108)
y_training_time_108 = np.array([d[108]['training_time'] for d in all_data_0]) / 3600 # max(y_training_time_108)

plt.figure(figsize=(15,6))
plt.xlim(0, max(y_training_time_108))
sns.distplot(y_training_time_4_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Mean Density of training_time 4e", rug=False)
sns.distplot(y_training_time_12_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Mean Density of training_time 12e", rug=False)
sns.distplot(y_training_time_36_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Mean Density of training_time 36e", rug=False)

sns.distplot(y_training_time_108_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Mean Density of training_time 108e", rug=False)

sns.distplot(y_training_time_4, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of training_time 4e", rug=False)
sns.distplot(y_training_time_12, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 12e", rug=False)
sns.distplot(y_training_time_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = " Density of training_time 36e", rug=False)

sns.distplot(y_training_time_108, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "Density of training_time 108e", rug=False)

plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Training time (H)')
plt.show()

# %%
mean_perf_half = mean_perf_half1 + mean_perf_half2


y_training_time_4_m = np.array([d[4]['kappaCohen_test'] for d in mean_perf_half]) #/3600 # max(y_training_time_108)
y_training_time_12_m = np.array([d[12]['kappaCohen_test'] for d in mean_perf_half]) #/ 3600 #max(y_training_time_108)
y_training_time_36_m = np.array([d[36]['kappaCohen_test'] for d in mean_perf_half]) #/ 3600 #max(y_training_time_108)
y_training_time_108_m = np.array([d[108]['kappaCohen_test'] for d in mean_perf_half]) #/ 3600 # max(y_training_time_108)


all_data_0 = [ dt for (m, op, dt) in read_data_1['trial_0']] + [ dt for (m, op, dt) in read_data_2['trial_0']]

y_training_time_4 = np.array([d[4]['kappaCohen_test'] for d in all_data_0]) #/3600 # max(y_training_time_108)
y_training_time_12 = np.array([d[12]['kappaCohen_test'] for d in all_data_0]) #/ 3600 #max(y_training_time_108)
y_training_time_36 = np.array([d[36]['kappaCohen_test'] for d in all_data_0]) #/ 3600 #max(y_training_time_108)
y_training_time_108 = np.array([d[108]['kappaCohen_test'] for d in all_data_0]) #/ 3600 # max(y_training_time_108)

# %%
plt.figure(figsize=(15,6))
plt.xlim(0, max(y_training_time_12)) #)108))
sns.distplot(y_training_time_12_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Mean Density of training_time 12e", rug=False)

sns.distplot(y_training_time_12, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 12e", rug=False)
          

plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa)')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.xlim(0, max(y_training_time_36)) #)108))
sns.distplot(y_training_time_36_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Mean Density of training_time 36e", rug=False)

sns.distplot(y_training_time_36, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 36e", rug=False)
          

plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.xlim(min(y_training_time_108), max(y_training_time_108))
sns.distplot(y_training_time_108_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Mean Density of training_time 108e", rug=False)

sns.distplot(y_training_time_108, hist = False, kde = True,
                 kde_kws = {'linewidth': 1},
                 label = "Density of training_time 108e", rug=False)
          

plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %% [markdown]
# # Study of variability of performances for various runs (N=3)

# %%
std_perf_half = std_perf_half1 + std_perf_half2
mean_perf_half = mean_perf_half1 + mean_perf_half2
N_confidence_interval_3_samples = 4.30 #
# https://stats.stackexchange.com/questions/230171/is-it-meaningful-to-calculate-standard-deviation-of-two-numbers
#https://en.wikipedia.org/wiki/Standard_deviation
attribute = 'kappaCohen_test' #'training_time' #'kappaCohen_test'

y_training_time_4_m = np.array([d[4][attribute] for d in mean_perf_half]) #/3600 # max(y_training_time_108)
y_training_time_12_m = np.array([d[12][attribute] for d in mean_perf_half]) #/ 3600 #max(y_training_time_108)
y_training_time_36_m = np.array([d[36][attribute] for d in mean_perf_half]) #/ 3600 #max(y_training_time_108)
y_training_time_108_m = np.array([d[108][attribute] for d in mean_perf_half]) #/ 3600 # max(y_training_time_108)


y_training_time_4_std = np.array([d[4][attribute] for d in std_perf_half]) #/3600 # max(y_training_time_108)
y_training_time_12_std = np.array([d[12][attribute] for d in std_perf_half]) #/ 3600 #max(y_training_time_108)
y_training_time_36_std = np.array([d[36][attribute] for d in std_perf_half]) #/ 3600 #max(y_training_time_108)
y_training_time_108_std = np.array([d[108][attribute] for d in std_perf_half]) #/ 3600 # max(y_training_time_108)

plt.figure(figsize=(15,6))
plt.xlim(0,)


plt.xlim(min(y_training_time_4_m - N_confidence_interval_3_samples* 
             y_training_time_4_std), 
         max(y_training_time_4_m + N_confidence_interval_3_samples* 
             y_training_time_4_std))

sns.distplot(y_training_time_4_m - N_confidence_interval_3_samples * y_training_time_4_std, 
                 hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "MEAN - STD Density of training_time 4e", rug=False)
sns.distplot(y_training_time_4_m, hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "MEAN Density of training_time 4e", rug=False)

sns.distplot(y_training_time_4_m + N_confidence_interval_3_samples * y_training_time_4_std, 
                 hist = False, kde = True,
                 kde_kws = {'linewidth': 1}, 
                 label = "MEAN +  STD Density of training_time 4e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper right')
plt.xlabel('Kappa')
plt.show()

# %%
plt.figure(figsize=(15,6))
#plt.xlim(0,)
plt.xlim(0, 1.1)
kwargs = {'cumulative': True, 'linewidth': 1}
#plt.xlim(min(y_training_time_4_m - N_confidence_interval_3_samples * y_training_time_4_std), 
#         1) #max(y_training_time_4_m + y_training_time_4_std))

sns.distplot(y_training_time_4_m - N_confidence_interval_3_samples * y_training_time_4_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)

sns.distplot(y_training_time_4_m, hist = False, kde = True,
                 kde_kws = kwargs, 
                 label = "MEAN Density - 4e", rug=False)

sns.distplot(y_training_time_4_m + N_confidence_interval_3_samples * y_training_time_4_std, 
             hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper left')
plt.xlabel('Kappa')
plt.show()

# %%
plt.figure(figsize=(15,8))
kwargs = {'cumulative': True, 'linewidth': 1}
#plt.xlim(min(y_training_time_12_m - y_training_time_12_std), 
#         max(y_training_time_12_m + y_training_time_12_std))
plt.xlim(0, 1.1)
sns.distplot(y_training_time_12_m - N_confidence_interval_3_samples * y_training_time_12_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)
                 #kde_kws = kwargs, 
                 #label = "MEAN - STD Density of training_time 12e", rug=False)
sns.distplot(y_training_time_12_m, hist = False, kde = True,
                 kde_kws = kwargs, 
                 label = "MEAN Density - 12e", rug=False)

sns.distplot(y_training_time_12_m + N_confidence_interval_3_samples * y_training_time_12_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False, 
                 #hist_kws = {'cumulative': False},
                 ) 
                 #kde_kws = kwargs, 
                 #label = "MEAN + STD Density of training_time 12e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper left')
plt.xlabel('Kappa')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.xlim(0, 1.1)
#plt.xlim(0.2, 1)
#plt.xlim(min(y_training_time_36_m - y_training_time_36_std), 
#        1.0) #max(y_training_time_36_m + y_training_time_36_std))
kwargs = {'cumulative': True, 'linewidth': 1}

sns.distplot(y_training_time_36_m - N_confidence_interval_3_samples * y_training_time_36_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)
                 #kde_kws = kwargs, 
                 #label = "MEAN - STD Density of training_time 36e", rug=False)
sns.distplot(y_training_time_36_m, hist = False, kde = True,
            kde_kws = kwargs, 
            label = "MEAN Density - 36e", rug=False
            )
sns.distplot(y_training_time_36_m  + N_confidence_interval_3_samples * y_training_time_36_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)
                 #kde_kws = kwargs, 
                # kde_kws = kwargs, 
                #label = "MEAN + STD Density of training_time 36e", rug=True)
#plt.axhline(y=1)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper left')
plt.xlabel('Kappa')
plt.show()

# %%
plt.figure(figsize=(15,8))
plt.xlim(min(y_training_time_108_m - y_training_time_108_std), 
1)#         max(y_training_time_108_m + y_training_time_108_std))

kwargs = {'cumulative': True, 'linewidth': 1}

sns.distplot(y_training_time_108_m - N_confidence_interval_3_samples * y_training_time_108_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)
                 #kde_kws = kwargs,
                 #label = "MEAN - STD Density of training_time 108e", rug=False)

sns.distplot(y_training_time_108_m, hist = False, kde = True,
                 kde_kws= kwargs,
                 label = "MEAN Density - 108e", rug=True)

sns.distplot(y_training_time_108_m + N_confidence_interval_3_samples * y_training_time_108_std, 
                 hist = False, kde = True,
                 kde_kws = {'cumulative': True, 'linestyle':'--'},  
                 label = "95% Confidence limt", rug=False)
                 #kde_kws = kwargs ,
                 #label = "MEAN + STD Density of training_time 108e", rug=False)
plt.title(label='LCZ42 - KDE - 35% of Training set - Batch Size of 128 - 100 Samples')
plt.legend(loc='upper left')
plt.xlabel('Kappa')
plt.show()

# %% [markdown]
# # Study of Robustness:

# %% [markdown]
# ## Across training regimes

# %%
len_t0_half = 50

mean_perf_half1 = []
std_perf_half1 = []

for m_i in range(len_t0_half):
    m0, op0, d0 = read_data_1['trial_0'][m_i]
    m1, op1, d1 = read_data_1['trial_1'][m_i]
    m2, op2, d2 = read_data_1['trial_2'][m_i]
    
    assert np.all(m0 == m1) and np.all(m1 == m2)
    assert np.all(op0 == op1) and np.all(op1 == op2)
    
    d_mean = {}
    d_std = {}
    all_regimes = [4, 12, 36, 108]
    d0_keys = [*d0]
    d1_keys = [*d1]
    d2_keys = [*d2]
    assert d0_keys == all_regimes and d1_keys == all_regimes and d2_keys == all_regimes
    
    all_attributes = [*d0[all_regimes[0]]]

    for r_i in all_regimes:
        d_mean[r_i] = {}
        d_std[r_i] = {}
    
        for at_i in all_attributes:
            d_mean[r_i][at_i] = np.mean([d0[r_i][at_i], d1[r_i][at_i], d2[r_i][at_i]])            
            d_std[r_i][at_i] = np.std([d0[r_i][at_i], d1[r_i][at_i], d2[r_i][at_i]])
            #print(d0[r_i][at_i], d0[r_i][at_i], d0[r_i][at_i])
    mean_perf_half1.append((m0, op0, d_mean))
    #std_perf_half1.append(d_std)

# %%
len_t0_half = 50

mean_perf_half2 = []
std_perf_half2 = []

for m_i in range(len_t0_half):
    m0, op0, d0 = read_data_2['trial_0'][m_i]
    m1, op1, d1 = read_data_2['trial_1'][m_i]
    #m2, op2, d2 = read_data_2['trial_2'][m_i]
    
    assert np.all(m0 == m1) #and np.all(m1 == m2)
    assert np.all(op0 == op1) #and np.all(op1 == op2)
    
    d_mean = {}
    d_std = {}
    all_regimes = [4, 12, 36, 108]
    d0_keys = [*d0]
    d1_keys = [*d1]
    #d2_keys = [*d2]
    assert d0_keys == all_regimes and d1_keys == all_regimes #and d2_keys == all_regimes
    
    all_attributes = [*d0[all_regimes[0]]]

    for r_i in all_regimes:
        d_mean[r_i] = {}
        d_std[r_i] = {}
    
        for at_i in all_attributes:
            d_mean[r_i][at_i] = np.mean([d0[r_i][at_i], d1[r_i][at_i]]) #, d2[r_i][at_i]])            
            d_std[r_i][at_i] = np.std([d0[r_i][at_i], d0[r_i][at_i]]) #, d0[r_i][at_i]])
            
    mean_perf_half2.append((m0, op0, d_mean))
    
    #mean_perf_half2.append(d_mean)
    #std_perf_half2.append(d_std)

# %%
mean_perf_half = mean_perf_half1 + mean_perf_half2

# %%
def top_n(list_models, N=10, regime=108, key='kappaCohen_test'):
    
    sorted_by_key = sorted(list_models, key= lambda triplet: triplet[2][regime][key])
    
    top_n_idx = len(sorted_by_key) * N/100
    top_n_idx = round(top_n_idx)
    
    return sorted_by_key[-top_n_idx:]

# %%
N = 100
top_25_r_04 = top_n(mean_perf_half, N=N, regime=4, key='kappaCohen_test')
top_25_r_12 = top_n(mean_perf_half, N=N, regime=12, key='kappaCohen_test')
top_25_r_36 = top_n(mean_perf_half, N=N, regime=36, key='kappaCohen_test')
top_25_r_108 = top_n(mean_perf_half, N=N, regime=108, key='kappaCohen_test')

# %%
top_25_r_4_models = [(m4, o4) for (m4, o4, _) in top_25_r_04]
top_25_r_12_models = [(m12, o12) for (m12, o12, _) in top_25_r_12]
top_25_r_36_models = [(m36, o36) for (m36, o36, _) in top_25_r_36]
top_25_r_108_models = [(m108, o108) for (m108, o108, _) in top_25_r_108]

# %%
cross_4_12 = []
cross_4_12_36 = []
cross_all = []

for duo_i in top_25_r_04:
    # in R = 12 
    for duo_j in top_25_r_12:
        if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
            cross_4_12.append(duo_i)

for duo_i in cross_4_12:
    # in R = 12 
    for duo_j in top_25_r_36_models:
        if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
            cross_4_12_36.append(duo_i)
            
for duo_i in cross_4_12_36:
    # in R = 12 
    for duo_j in top_25_r_108:
        if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
            cross_all.append(duo_i)

# %%
len(cross_4_12), len(cross_4_12_36), len(cross_all)
# Out:
# (100, 100, 100)

# %% [markdown]
# ## Plot evolution of Top-N intersection

# %%
def Evol_top_N_relatively_4(relative=False):
    size_inter = []
    total_size = len(mean_perf_half)
    for N in range(1, total_size + 1):
        top_25_r_04 = top_n(mean_perf_half, N=N, regime=4, key='kappaCohen_test')
        top_25_r_12 = top_n(mean_perf_half, N=N, regime=12, key='kappaCohen_test')
        top_25_r_36 = top_n(mean_perf_half, N=N, regime=36, key='kappaCohen_test')
        top_25_r_108 = top_n(mean_perf_half, N=N, regime=108, key='kappaCohen_test')

        top_25_r_4_models = [(m4, o4) for (m4, o4, _) in top_25_r_04]
        top_25_r_12_models = [(m12, o12) for (m12, o12, _) in top_25_r_12]
        top_25_r_36_models = [(m36, o36) for (m36, o36, _) in top_25_r_36]
        top_25_r_108_models = [(m108, o108) for (m108, o108, _) in top_25_r_108]

        cross_4_12 = []
        cross_4_12_36 = []
        cross_all = []

        for duo_i in top_25_r_04:
            # in R = 12 
            for duo_j in top_25_r_12:
                if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
                    cross_4_12.append(duo_i)

        for duo_i in cross_4_12:
            # in R = 12 
            for duo_j in top_25_r_36_models:
                if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
                    cross_4_12_36.append(duo_i)

        for duo_i in cross_4_12_36:
            # in R = 12 
            for duo_j in top_25_r_108:
                if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
                    cross_all.append(duo_i)
        if relative:
            len_top_4 = len(top_25_r_4_models)
            assert len_top_4 == N
        else:
            len_top_4 = total_size
        
        l0, l1, l2, l3 = len(top_25_r_4_models) / len_top_4, len(cross_4_12)/len_top_4, len(cross_4_12_36)/len_top_4, len(cross_all)/len_top_4
        size_inter.append((l0 * 100, l1 * 100, l2 * 100, l3 * 100))
    return size_inter

# %% [markdown]
# ### TOP-N% : Absolute number of models

# %%
size_inter_abs = Evol_top_N_relatively_4(relative=False)

# %%
title = 'Robustness accross time: models remaining Top-N% after being Top-N% at 4 epochs \n LCZ42 - SEN2 - D2 - metric of comparison : Kappa'
plt.figure(figsize=(16,8))
plt.ylim(0, 100) #len(mean_perf_half))
plt.xlim(0, 100)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter_abs], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter_abs], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter_abs], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter_abs], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Top-N (in %)')
plt.ylabel('Size of intersection (Number of models)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.ylim(0, 40) #len(mean_perf_half))
plt.xlim(0, 35)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter_abs], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter_abs], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter_abs], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter_abs], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Top-N (in %)')
plt.ylabel('Size of intersection (Number of models)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %% [markdown]
# ### TOP-N% : Relative number of models wrt to 4 epochs

# %%
size_inter = Evol_top_N_relatively_4(relative=True)

# %%
plt.figure(figsize=(16,8))
plt.ylim(0, 110) #len(mean_perf_half))
plt.xlim(0, 100)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Top-N (in %)')
plt.ylabel('Size of intersection (in %)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.ylim(0, 110) #len(mean_perf_half))
plt.xlim(0, 35)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Top-N (in %)')
plt.ylabel('Size of intersection (in %)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %% [markdown]
# ## Evolution of Failures: the Bottom-N% performers accross regimes

# %%
def bottom_n(list_models, N=10, regime=108, key='kappaCohen_test'):
    
    sorted_by_key = sorted(list_models, key= lambda triplet: triplet[2][regime][key])
    
    bottom_n_idx = len(sorted_by_key) * N/100
    bottom_n_idx = round(bottom_n_idx)
    
    return sorted_by_key[:bottom_n_idx]

# %%
def Evol_bottom_N_relatively_4(relative=False):
    size_inter = []
    total_size = len(mean_perf_half)
    for N in range(1, total_size + 1):
        bottom_25_r_04 = bottom_n(mean_perf_half, N=N, regime=4, key='kappaCohen_test')
        bottom_25_r_12 = bottom_n(mean_perf_half, N=N, regime=12, key='kappaCohen_test')
        bottom_25_r_36 = bottom_n(mean_perf_half, N=N, regime=36, key='kappaCohen_test')
        bottom_25_r_108 = bottom_n(mean_perf_half, N=N, regime=108, key='kappaCohen_test')

        bottom_25_r_4_models = [(m4, o4) for (m4, o4, _) in bottom_25_r_04]
        bottom_25_r_12_models = [(m12, o12) for (m12, o12, _) in bottom_25_r_12]
        bottom_25_r_36_models = [(m36, o36) for (m36, o36, _) in bottom_25_r_36]
        bottom_25_r_108_models = [(m108, o108) for (m108, o108, _) in bottom_25_r_108]

        cross_4_12 = []
        cross_4_12_36 = []
        cross_all = []

        for duo_i in bottom_25_r_04:
            # in R = 12 
            for duo_j in bottom_25_r_12:
                if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
                    cross_4_12.append(duo_i)

        for duo_i in cross_4_12:
            # in R = 12 
            for duo_j in bottom_25_r_36_models:
                if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
                    cross_4_12_36.append(duo_i)

        for duo_i in cross_4_12_36:
            # in R = 12 
            for duo_j in bottom_25_r_108:
                if np.all(duo_i[0] == duo_j[0]) and np.all(duo_i[1] == duo_j[1]) :
                    cross_all.append(duo_i)
        if relative:
            len_bottom_4 = len(bottom_25_r_4_models)
            assert len_bottom_4 == N
        else:
            len_bottom_4 = total_size
        
        l0, l1, l2, l3 = len(bottom_25_r_4_models) / len_bottom_4, len(cross_4_12)/len_bottom_4, len(cross_4_12_36)/len_bottom_4, len(cross_all)/len_bottom_4
        size_inter.append((l0 * 100, l1 * 100, l2 * 100, l3 * 100))
    return size_inter

# %% [markdown]
# ### Absolute values: the Bottom-N% performers accross regimes

# %%
size_inter_abs_bottom = Evol_bottom_N_relatively_4(relative=False)

# %%
title = 'Failure accross time: models remaining Bottom-N% after being Bottom-N% at 4 epochs \n LCZ42 - SEN2 - D2 - metric of comparison : Kappa'
plt.figure(figsize=(16,8))
plt.ylim(0, 100) #len(mean_perf_half))
plt.xlim(0, 100)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter_abs_bottom], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter_abs_bottom], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter_abs_bottom], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter_abs_bottom], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Bottom-N (in %)')
plt.ylabel('Size of intersection (Number of models)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.ylim(0, 40) #len(mean_perf_half))
plt.xlim(0, 35)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter_abs_bottom], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter_abs_bottom], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter_abs_bottom], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter_abs_bottom], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Top-N (in %)')
plt.ylabel('Size of intersection (Number of models)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %%
size_inter_relative_bottom = Evol_bottom_N_relatively_4(relative=True)

# %%
title = 'Failure accross time: models remaining Bottom-N% after being Bottom-N% at 4 epochs \n LCZ42 - SEN2 - D2 - metric of comparison : Kappa'
plt.figure(figsize=(16,8))
plt.ylim(0, 102) #len(mean_perf_half))
plt.xlim(0, 100)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter_relative_bottom], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter_relative_bottom], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter_relative_bottom], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter_relative_bottom], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Bottom-N (in %)')
plt.ylabel('Size of intersection (%)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %%
title = 'Failure accross time: models remaining Bottom-N% after being Bottom-N% at 4 epochs \n LCZ42 - SEN2 - D2 - metric of comparison : Kappa'
plt.figure(figsize=(16,8))
plt.ylim(0, 65) #len(mean_perf_half))
plt.xlim(0, 35)
#plt.set_xticks(5)
plt.plot(range(1, 101), [s[0] for s in size_inter_relative_bottom], label = "Robust accross: [4] epochs (Reference)",)
plt.plot(range(1, 101), [s[1] for s in size_inter_relative_bottom], label = "Robust accross: [4, 12] epochs",)
plt.plot(range(1, 101), [s[2] for s in size_inter_relative_bottom], label = "Robust accross: [4, 12, 36] epochs)",)
plt.plot(range(1, 101), [s[3] for s in size_inter_relative_bottom], label = "Robust accross: [4, 12, 36, 108] epochs",)
plt.title(label=title)
plt.legend(loc='lower right')
plt.xlabel('Bottom-N (in %)')
plt.ylabel('Size of intersection (%)')
#plt.axvline(x=10, color='red')
#plt.axvline(x=25, color='red')
plt.show()

# %% [markdown]
# #### What do models remaining top/bottom-N accross regimes have in common ?

# %% [markdown]
# ## Project robustness into 2D Landscape: Plot contour around top N performers ?

# %% [markdown]
# ## Across datasets
